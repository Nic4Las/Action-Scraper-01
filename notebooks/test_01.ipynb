# %%
import asyncio
import functools
import random
import aiometer
import httpx
from selectolax.parser import HTMLParser
from tqdm.asyncio import trange, tqdm
from pydantic import BaseModel
from typing import List, Dict, Any, Optional
from enum import Enum, StrEnum

from rich import print as pprint

# %%
class Labels(StrEnum):
    origin = "Original"
    fan_fiction = "Fan Fiction"
    unknown = "Unknown"


class NovelData(BaseModel):
    title: str
    fiction_id: str
    link: str
    tags: List[str]
    lable: Labels
    following_count: int
    rating: float
    page_count: int
    view_count: int
    chapters_count: int
    last_update: int
    description: str
    description_hash: int

# %%
client = httpx.AsyncClient()

# %%
async def createTaskByPageNr(client: httpx.AsyncClient, pageNr: int):
    url = f"https://www.royalroad.com/fictions/search?page={pageNr}&orderBy=release_date"
    response = await client.get(url)
    return response

# %%
async def parsePage(response: httpx.Response, debug = False) -> list[NovelData]:
    if response.status_code != 200:
        return []
    tree = HTMLParser(response.text)
    novels = []

    for novel in tree.css("div.row.fiction-list-item"):

        title = novel.css_first("h2.fiction-title a").text() or "No Title"
        
        url = "https://www.royalroad.com" + novel.css_first('h2.fiction-title a').attributes['href'] or "No Link"
        
        fiction_id = url.split("/")[-2] or -1
        
        tags = [tag.text() for tag in novel.css('span.tags a')] or []
        
        lable = novel.css_first("span.label.label-default.label-sm.bg-blue-hoki").text() or Labels.unknown
        
        rating = novel.css_first('.star').attributes['title'] or -1
        
        following_count = int(novel.css_first("i.fa.fa-users").parent.css_first('span').text().replace('Followers', '').replace(",", "") or -1)
        
        page_count = int(novel.css_first("i.fa.fa-book").parent.css_first('span').text().replace('Pages', '').replace(",", "") or -1)
        
        view_count = int(novel.css_first("i.fa.fa-eye").parent.css_first('span').text().replace('Views', '').replace(",", "") or -1)
        
        chapter_count = int(novel.css_first("i.fa.fa-list").parent.css_first('span').text().replace('Chapters', '').replace(",", "") or -1)
        
        last_update = int(novel.css_first("i.fa.fa-calendar").parent.css_first('time').attributes['unixtime'] or -1)
        
        description = novel.css_first("div.margin-top-10.col-xs-12").text().strip() or "No Description"
        
        novels.append(NovelData(
            title=title,
            fiction_id=fiction_id,
            link=url,
            tags=tags,
            lable=lable,
            following_count=following_count,
            rating=rating,
            page_count=page_count,
            view_count=view_count,
            chapters_count=chapter_count,
            last_update=last_update,
            description=description,
            description_hash=hash(description)
        ))

    return novels

# %%
async def getNovelsByPageNr(client: httpx.AsyncClient, pageNr: int):
    response = await createTaskByPageNr(client, pageNr)
    return await parsePage(response)

# %%
testResponse = await createTaskByPageNr(client, 1)
pprint((await parsePage(testResponse))[0])
# Out:
# NovelData(
#     title='A Fortress of Pebbles',
#     fiction_id='88582',
#     link='https://www.royalroad.com/fiction/88582/a-fortress-of-pebbles',
#     tags=[
#         'Urban Fantasy',
#         'Female Lead',
#         'Sci-fi',
#         'Contemporary',
#         'Adventure',
#         'Fantasy',
#         'Magic',
#         'Low Fantasy'
#     ],
#     lable=<Lables.origin: 'Original'>,
#     following_count=1,
#     rating=0.0,
#     page_count=3,
#     view_count=5,
#     chapters_count=1,
#     last_update=1718486502,
#     description='Former guardians of Earth must take refuge there, inadvertently becoming the apocalypse they are
# sworn to prevent.',
#     description_hash=-4595259820883119702
# )

# %%
res = list()

async with httpx.AsyncClient() as client:
    tasks = [createTaskByPageNr(client, i) for i in range(1, 3)]
    res = await tqdm.gather(*tasks)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]c:\Users\Niclas\.conda\envs\semsearch\Lib\site-packages\anyio\_core\_sockets.py:162: RuntimeWarning: coroutine 'AsyncClient.get' was never awaited
#   async def try_connect(remote_host: str, event: Event) -> None:
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 100%|██████████| 2/2 [00:00<00:00,  8.16it/s]

# %%
pageNrs = list(range(1, 30))

async with aiometer.amap(
    functools.partial(getNovelsByPageNr, client),
    tqdm(pageNrs),
    max_at_once=5,
    max_per_second=2,
) as res:
    async for r in res:
        print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 pageNrs = list(range(1, 30))
# ----> 3 async with aiometer.amap(
#       4     functools.partial(getNovelsByPageNr, client),
#       5     tqdm(pageNrs),
#       6     max_at_once=5,
#       7     max_per_second=2,
#       8 ) as res:
#       9     async for r in res:
#      10         print(r)
#
# NameError: name 'aiometer' is not defined

# %%
res[0].text
# Out:
# '<!DOCTYPE html>\n<!--[if IE 8]> <html lang="en" class="ie8 no-js"> <![endif]-->\n<!--[if IE 9]> <html lang="en" class="ie9 no-js"> <![endif]-->\n<!--[if !IE]><!-->\n<html lang="en">\n<!--<![endif]-->\n<head>\n    <meta charset="utf-8"/>\n    <title>Search Page | Royal Road</title>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0"/>\n    \n    \n    <link rel="canonical" href="https://www.royalroad.com/search"/>\n    <meta name="keywords" content="free books online; web fiction; free; book; novel; royal road; royalroadl; rrl; legends; fiction">\n    <meta name="description" content="Search Royal Road for new stories to read or stories whose title you have forgotten">\n    <meta property="fb:app_id" content="1585608748421060"/>\n    <meta property="og:locale" content="en_US">\n    <meta property="og:type" content="website">\n    <meta property="og:title" content="Search Page | Royal Road">\n    <meta property="og:description" content="Search Royal Road for new stories to read or stories whose title you have forgotten">\n    <meta property="og:url" content="https://www.royalroad.com/search">\n    <meta property="og:site_name" content="Royal Road">\n    <meta property="og:image" content="/dist/img/logo/rr-logo-square-silver-gold-large.png">\n    <meta name="twitter:card" content="summary">\n    <meta name="twitter:description" content="Search Royal Road for new stories to read or stories whose title you have forgotten">\n    <meta name="twitter:title" content="Search Page | Royal Road">\n    <meta name="twitter:image" content="https://www.royalroad.com/dist/img/logo/rr-logo-square-silver-gold-large.png">\n\n    <link href="https://fonts.googleapis.com/css2?family=Open+Sans:ital,wght@0,300;0,400;0,600;0,700;1,400&display=swap" rel="stylesheet">\n    <link type="text/css" rel="stylesheet" href="/dist/vendor.css?v=dk6Lx2FNSWiQrI59cVd1k4LY4MC0xZ1k6_QX6wgREKU" />\n    <link type="text/css" rel="stylesheet" href="/dist/site-light.css?v=Nwxc6fz8HnMBh51iEgQhlqbdf09zZybHsDX4WaPlbJM" />\n    \n    <link rel="icon" href="/icons/android-chrome-192x192.png?v=20200125" sizes="192x192" />\n    <link rel="shortcut icon" href="/icons/favicon.ico?v=20200125" sizes="16x16 24x24 32x32"/>\n    <link rel="apple-touch-icon" sizes="180x180" href="/icons/apple-icon-180x180.png?v=20200125">\n    <link rel="icon" type="image/png" sizes="16x16" href="/icons/favicon-16x16.png?v=20200125">\n    <link rel="icon" type="image/png" sizes="32x32" href="/icons/favicon-32x32.png?v=20200125">\n    <link rel="manifest" href="/manifest.json">\n    <meta name="msapplication-TileColor" content="#ffffff">\n    <meta name="msapplication-TileImage" content="/icons/ms-icon-144x144.png">\n    <meta name="theme-color" content="#FFFFFF">\n        <meta name="sentry-trace" content="f3cc98de9618482391feae2f21580a34-8cf3f4d884bdd8f2"/>\n        <meta name="baggage" content="sentry-trace_id=f3cc98de9618482391feae2f21580a34, sentry-public_key=de5ce8f509e7458780cbb83f5b040bf0, sentry-release=RoyalRoad.Web.Website%404.1.20240611.2, sentry-environment=production">\n    <script type="text/javascript">\n        window.royalroad = window.royalroad || {init: []};\n        window.royalroad.isPremium = false;\n        window.royalroad.version = "RoyalRoad.Web.Website@"+"4.1.20240611.2";\n        window.royalroad.userId = 0;\n        window.royalroad.environment = "Production";\n        window.royalroad.actionRoute = "Fictions.Search";\n        window.royalroad.username = "";\n        window.royalroad.betaFeatures = false;\n        \n        window.dateFormat = "yyyy-MM-dd";\n        window.dateTimeFormat = "yyyy-MM-dd HH:mm";\n    </script>\n    <script type="text/javascript" src="https://cdnjs.cloudflare.com/polyfill/v3/polyfill.min.js?features=default%2Ces6"></script>\n<script>(\'WeakMap\' in window && \'IntersectionObserver\' in window && \'assign\' in Object && \'fetch\' in window||document.write("\\u003C ...
